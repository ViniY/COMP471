# %% [markdown]
# # COMP471 Assignment 1

# %% [markdown]
# <font color='blue' size = "5">Question 1.a
# </font>
# <font size=3>
#
# Events can be
#
# | Events | |
# |------|------|
# | GG |  "two gold coins" |
# | GS | "one gold and one silver" |
# | SS  | "two silver coins" |
#
#
# $$ \frac{P(GG| one Gold seen)}{P(GS| one Gold seen)} = \frac{P(g|GG) \times P(GG)}{P(g|GS)\times P(GS)} \times  \frac{P(g)}{P(g)}$$
#
#
# $$P(GG)= P(GS)= \frac{1}{3}$$
# $$P(g|GG) = 1$$
# $$P(g|GS) =\frac{1}{2}$$
#
# Therefore $$ \frac{P(GG| one Gold seen)}{P(GS| one Gold seen)} =\frac{2}{1}$$
#
# And  P(GG| one Gold seen) + P(GS| one Gold seen) = 1
#
#
# Hence P(GG|g) = 2/3</font>

# %% [markdown]
# <font color='blue' size = "5">Question 1.b
# </font>
#
# <font size=3>
# Assuming brothers can share the same ages. Which means there can be 13 combinations, showing in the following table.
# Denote
# $$Fred->F$$
# $$Alf ->A$$
# $$Bob ->B$$
#
# |Number| Combination|
# |------|------------|
# |1|F>A>B|
# |2|F>B>A|
# |3|A>B>F|
# |4|A>F>B|
# |5|B>A>F|
# |6|B>F>A|
# |7|A=B=F|
# |8|A=B>F|
# |9|A=F>B|
# |10|B=F>A|
# |11|F>A=B|
# |12|A>F=B|
# |13|B>A=F|
#
# (1) As showing in the table, there can be 5 out 13 combinations that Fred is older than Bob.
#
# hence $$P(F>B) = \frac{5}{13}$$
#
#
# (2)
# From the table there are 5 combinations that F>A gives $$P(F>A) =\frac {5}{13} $$
# And 3 combinations that F>A and F>B that gives $$ P(F>A,F>B) = \frac{3}{13}$$
#
# Then,
# $$P(F>B|F>A) = \frac{P(F>B , F>A)} {P(F>A)} = \frac{3}{5}$$
#
#
# </font>

# %% [markdown]
# <font color='blue' size = "5">Question 1.c
# </font>
#
# <font size=3>
# The information gives us D that is 140 heads and 110 tails.
# The hypothesis gives that $$ P(D|H) \leq 0.07$$
#
# The prior of this is P(H). It is unknown from the given information and not it is not being considered in this argument.$$$$
# I think we still can make two hypothesis that is (1) The coin is biased (2)The coin is even.
# And use $$\frac{P(H1|D)}{P(H2|D)}$$ to find out ratio in between, and determine which one is better.
# </font>

# %% [markdown]
# <font color='blue' size = "5">Question 1.d
# </font>
#
# <font size=3>
#
# (1):
# $$P(Head| D) = \frac{1}{Z} \int_0^1 \theta^k \times (1-\theta)^{n-k}\times \theta d\theta $$
# The theta above representing the prior, in this case that is $$6\theta(1-\theta)$$
#
#
#
# K = 2 and n = 3.
# It also must satisfy $$ 0\leq 6\theta(1-\theta) \leq 1$$
# As we put this back into the equation shows in the first line, we can get :
# $$ \frac{1}{Z} \int_0^1 (6^2(\theta-\theta^2)^2)(1-6\theta+6\theta^2)(6\theta-6\theta^2)d\theta$$
#
# Here  $$\frac{1}{Z}$$ is a normalization factor, and  $$(6^2(\theta-\theta^2)^2)(1-6\theta+6\theta^2)$$ is the posterior.
#
# $$ = \frac{1}{Z} \int_0^1 (6^3)(\theta-\theta^2)^3(1-6\theta+6\theta^2)d\theta$$
# $$ = \frac{1}{C} \int_0^1(\theta-\theta^2)^3(1-6\theta+6\theta^2)d\theta$$
# Here $$\frac{1}{C}=(6)^3 \times \frac{1}{Z}$$
# x^4/4 - (9 x^5)/5 + (9 x^6)/2 - (37 x^7)/7 + 3 x^8 - (2 x^9)/3
# $$ = \frac{1}{C} \int_0^1 6\theta^8 + 24\theta^7 - 37\theta^6 +27\theta^5- 9\theta^4 +\theta^3 d\theta$$
# After the integral we can find:
# $$\frac{1}{C}(\frac{6}{9} + 3 - \frac{37}{7} + \frac{27}{6} -\frac{9}{5} + \frac{1}{4})$$
# We can find out C by using Beta Distribution.
# </font>

# %% [markdown]
# <font size=5 color ="blue" > Q1.d.2</font>

# %% [markdown]
# <font size=3>
# As the information gives, there is no possibility that the coin biased to the head P(Bias to head) = 0 that is P(theta > 0.5) = 0 $$$$
# So the integral becomes from 0 to 0.5, and the integral from 0.5 to 1 is just zero.
#
# $$ = \frac{1}{Z} \int_0^{0.5} (6^3)(\theta-\theta^2)^3(1-6\theta+6\theta^2)d\theta$$
# $$ = \frac{1}{C} \int_0^{0.5}(\theta-\theta^2)^3(1-6\theta+6\theta^2)d\theta$$
# $$ = \frac{1}{C} \int_0^{0.5} 6\theta^8 + 24\theta^7 - 37\theta^6 +27\theta^5- 9\theta^4 +\theta^3 d\theta$$
#
# </font>

# %% [markdown]
# <font color='blue' size = "5">Question 1.e
# </font>
#
# <font size=3>
# The falsifiable theory proposed the more chances a theory can be wrong, but with the given evidence it is not wrong "yet," the more we should trust that theory. And in Ockham's Razor, we believe it is good to pick the simplest model that adequately explains the data. Like it describes three models in the book, M1 -> very simple model, M2-> medium, M3-> very complex one. Model 2 observes the given data with a reasonable degree of confidence, which also simpler than model 3. Model 2 could be wrong for more data, but with the given evidence, it can fit and has a higher degree of confidence. But we know it can go wrong when more data be observed. But it is not wrong, "yet."
#
# Regression problem can be a good example, considering we are given several data points having a parabola shape, like what we discussed in the lecture, a very complex polynomial model (w0+w1X+w2x^2....+wnx^n) could fit the given training data perfectly, but it could have a lower degree of confidence with the given data. Because it can predict more data set, therefore the probability spreads more widely and thinly. A simpler model (like y=w0+w1x + w2x^2) can also fit the data well and has a higher degree of confidence. We are usually likely to choose the simpler one. We know a simpler model has a greater chance to be wrong for more data, but with the given evidence, it is just right "yet."</font>

# %% [markdown]
# <font color='blue' size = "5">Question 2
# </font>
#
#
# <font color='blue' size = "2">Question 2.a
# </font>
#
#
# <font size=3>$$P(W) =N(W|W_0,V_0)$$
# Here we want to maximize $$Pr(y|x,W_0,V_0)$$</font>

# %% [markdown]
# <img src = "PGM.jpeg" style = "width :550px;height : 550px"/>

# %% [markdown]
# (ii):
# <font size=3>
#
# I think this should be an example of "Empirical Bayes". Using empirical bayes, we can compute the posterior on multiple levels of latent variables. It can be used in picking hyper-parameters. As described in the book, EB linear regression process choose $$\eta = (\alpha,\lambda)$$ where lambda is the precision of the observation noise and alpha is the precision of the prior. And to maximize the marginal likelihood.
# In the proposal, we integrate over the unknown prior, it then become the same as integrating over just w, which is also discussed in this part, it also known as evidence procedure. Then we want to maximize Pr(y|x,w0,V0) which is the marginal likelihood. Therefore, I think it follows the Empirical bayes procedures. </font>

# %% [markdown]
# <font color='blue' size = "4">Question 2.b
# </font>
#
# <font size=3>
#
# For computing the distance r = ||x-w||^2 we can use $$(x-W)^T(x-W) = x^Tx+W^TW-2xW^T$$
# </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as rng
import pandas as pd
# rng.seed(471)
Phi_s = []

# %%
def groundTruth(input):
#     out = np.sin(16*input)  *  np.exp(-5*input**2)
#     out = input**3
#     out = input -0.2
    out = np.tanh(10*input) 
    return(out)

def rngWeights(M, sigmaWeights, sigmaBiases):    # make up the random parameters for the input-to-hidden linear mapping.
    W = rng.normal(0,sigmaWeights,(M)) #yes, weird in that there's only 1 input dimension, built in. Sucks...
    B = rng.normal(0,sigmaBiases,(M))
    return (W,B)

def doDesignMatrix(W,B,x,active_func):    # projection of x, using those W,B and a 
                              # nonlinearity: Bishop denotes this Phi
                                #active_func determine which activation function we want to use 
                                # eg. 1 for relu 
                                # 2 for decreasing RBF
                                # 3 for increasing RBF
#     print("*"*40)
#     print("tha shape of W: ", np.shape(W))
#     print("the shape of x :", np.shape(x))
    
    if active_func == 1:
        Phi = np.maximum(0,np.outer(x,W) + B)  # the nonlinearity here is ReLU.
        Phi_s.append(Phi)
    
#     x_transpose = x.transpose()
#     W_transpose = W.transpose()
#     XX_T = x*x_transpose
#     WW_T = W*W_transpose
#     xW_T = np.outer(x,W_transpose)
#     R = 1
#     Phi = np.exp(-(h)/R)
#     print("XX_T : ", np.shape(XX_T))
#     print("WW_T : ", np.shape(WW_T))
#     print("xW_T : ", np.shape(xW_T))
#     r = XX_T + WW_T - 2*xW_T
#     Phi = np.exp(-r/(2))
#     output = np.exp( -0.5 * np.subtract.outer(x, W)**2)
    else: #RBFs
        hs=[]
        R = sigmaWeights/2
        for i in x:
            distance =0
            for j in W:
                if active_func == 2:
                        hs.append(np.exp(-((np.sqrt((i - j)** 2))**2)/(R**2))) # exp^(-r^2/R^2)
                if active_func == 3:
                        hs.append((np.sqrt((i - j)**2))**3)
        if active_func == 2 or active_func == 3:
            h = np.asarray(hs)
            h = h.reshape(len(x),len(W))
            Phi = h
            Phi_s.append(Phi)
#         print("distance shape : ",np.shape(h))
    
    
#     print("The shape of Phi :", np.shape(Phi))

    return(Phi)

# %%
M = 100   # number of basis functions (a.k.a. hidden units)
N = 10 # number of data items
Ntest = 100 # number of points to plot when showing the plotted lines


xData = 0.5*(1-2*rng.random((N,1)))
# xData = 0.5*np.array([-1,-.9,-.8,-.7,-.6,1,.9,.8,.7,.6]).reshape(N,1)
# xData = 0.5*np.array([1,.9,.8,.7,.6,.5,.4,.3,.2,.1]).reshape(N,1)


         
yData = groundTruth(xData)
x = np.linspace(-1,1,Ntest)#.reshape(Ntest,1)

# %%
# For the hid-to-output mapping:
alpha = 1.0 
beta = 1000.0

# For the input-to-hidden mapping:
sigmaWeights = 1.0
sigmaBiases  = 1.0

# %%
def BayesLinearRegression(W,B,alpha,beta,xData,xQuery,active_func):
    Phi = doDesignMatrix(W,B,xData,active_func)
    invS = alpha*np.eye(M) + beta*np.dot(Phi.transpose(),Phi)
    S = np.linalg.inv(invS)
    regMoorePenrose = beta*np.dot(S, Phi.transpose()) #nb. the beta here "undoes" the one inside invS
#     if(len(xData)<2):
#         print("small xData")
#         yData = []
#         yData.append(groundTruth(xData[0]))
#         yData = np.asarray(yData)
#     else:
#         print(yData)
        
#     print("yData_*:", yData)
        
    wLMS = np.dot(regMoorePenrose, yData)
    phi = doDesignMatrix(W,B,xQuery,active_func)
    y = np.dot(phi,wLMS)
    sig2 = 1/beta + np.diag(np.dot(np.dot(phi, S), phi.transpose())).reshape(y.shape) 
    return (y, sig2)

# %% [markdown]
# <font color='blue' size = "5">Using Relu
#
# </font>

# %%
fig=plt.figure(figsize=(18, 6))
LHS, RHS = plt.subplot(121), plt.subplot(122)

W,B = rngWeights(M,sigmaWeights,sigmaBiases)

y, sig2 = BayesLinearRegression(W,B,alpha,beta,xData,x,active_func = 1)

upper = np.ravel(y + 2*np.sqrt(sig2))
lower = np.ravel(y - 2*np.sqrt(sig2))
LHS.fill_between(np.ravel(x), lower, upper, facecolor='pink', interpolate=True, alpha=.5)
LHS.plot(x,y,'-r',alpha=1)
LHS.set_ylim(-2, 2)

# for the RHS, we just draw samples i.i.d at each x value in linspace
for i in range(200):
    z = rng.normal(y,np.sqrt(sig2))
    RHS.plot(x,z,'.b',alpha= 0.1)
    RHS.set_ylim(-2, 2)
    
LHS.plot(x,groundTruth(x),':g',xData,yData,'ok')
RHS.plot(xData,yData,'ok')

# %% [markdown]
# <font color='blue' size = "5">Using RBF decreasing with distance
# </font>

# %%
fig=plt.figure(figsize=(18, 6))
active_func = 2 # RBF decreasing with distance
LHS, RHS = plt.subplot(121), plt.subplot(122)

W,B = rngWeights(M,sigmaWeights,sigmaBiases)

y, sig2 = BayesLinearRegression(W,B,alpha,beta,xData,x,active_func)

upper = np.ravel(y + 2*np.sqrt(sig2))
lower = np.ravel(y - 2*np.sqrt(sig2))

LHS.fill_between(np.ravel(x), lower, upper, facecolor='pink', interpolate=True, alpha=.5)
LHS.plot(x,y,'-r',alpha=1)
LHS.set_ylim(-2,2)

# for the RHS, we just draw samples i.i.d at each x value in linspace
for i in range(200):
    z = rng.normal(y,np.sqrt(sig2))
    RHS.plot(x,z,'.b',alpha= 0.1)
    RHS.set_ylim(-2, 2)
LHS.plot(x,groundTruth(x),':g',xData,yData,'ok')
RHS.plot(xData,yData,'ok')

# %% [markdown]
# <font color='blue' size = "5">Using RBF increasing with distance
# </font>

# %%
fig=plt.figure(figsize=(18, 6))
active_func = 3 #RBF increasing with distance
LHS, RHS = plt.subplot(121), plt.subplot(122)

W,B = rngWeights(M,sigmaWeights,sigmaBiases)

y, sig2 = BayesLinearRegression(W,B,alpha,beta,xData,x,active_func)

upper = np.ravel(y + 2*np.sqrt(sig2))
lower = np.ravel(y - 2*np.sqrt(sig2))

LHS.fill_between(np.ravel(x), lower, upper, facecolor='pink', interpolate=True, alpha=.5)
LHS.plot(x,y,'-r',alpha=1)
LHS.set_ylim(-2,2)


# for the RHS, we just draw samples i.i.d at each x value in linspace
for i in range(200):
    z = rng.normal(y,np.sqrt(sig2))
    RHS.plot(x,z,'.b',alpha= 0.1)
    RHS.set_ylim(-2, 2)

errors = np.abs(y-groundTruth(x))

LHS.plot(x,groundTruth(x),':g',xData,yData,'ok')
RHS.plot(xData,yData,'ok')

# %% [raw]
# b(ii)
# The distribution of y in RBF have a thinner spread between -.75 to +0.75, compared to Relu. But RBF includes more non-linearity. The unexpected thing is model using Relu fits the real function that is in the groundTruth method better than using RBF.

# %% [markdown]
# <font color='blue' size = "5">Question 2.c
# </font>

# %% [markdown]
# <font color='blue' size = "5">decreasing with distance, one per data point </font>

# %%
active_func = 2 #RBF increasing with distance
# LHS, RHS = plt.subplot(121), plt.subplot(122)
N=1 #the number of data generate each time\

xData = []
xData = np.append(xData, (0.5 * (1 - 2 * rng.random((N, 1)))))
yData = groundTruth(xData)
W,B = rngWeights(M,sigmaWeights,sigmaBiases)
y_s=[]
plot = False
iterations = 15#giving how many data points in total

for i in range(iterations): # in order to have less graphs, 2 points per graph in iteration less than 10 then 5 points -> graph
    if i < 11:
        if i % 2== 0 or i==0:
            plot = True
        else:
            plot = False
    elif i % 5 == 0:
        plot = True
    else:
        plot = False


    xData = np.append(xData, (0.5 * (1 - 2 * rng.random((N, 1)))))
    yData = groundTruth(xData)
    y, sig2 = BayesLinearRegression(W,B,alpha,beta,xData,x,active_func)
    upper = np.ravel(y + 2*np.sqrt(sig2))
    lower = np.ravel(y - 2*np.sqrt(sig2))

    if plot:
        LHS = plt.subplot()
        LHS.fill_between(np.ravel(x), lower, upper, facecolor='pink', interpolate=True, alpha=.5)
        LHS.plot(x, y, '-r', alpha=1)
        LHS.set_ylim(-2, 2)
        LHS.plot(x, groundTruth(x), ':g', xData, yData, 'ok')
        print(i)
        plt.show()

# # for the RHS, we just draw samples i.i.d at each x value in linspace
# for i in range(200):
#     z = rng.normal(y,np.sqrt(sig2))
#     RHS.plot(x,z,'.b',alpha= 0.1)
#     RHS.set_ylim(-2, 2)
#
# errors = np.abs(y-groundTruth(x))

LHS.plot(x,groundTruth(x),':g',xData,yData,'ok')
# RHS.plot(xData,yData,'ok')
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# ...

# %% [markdown]
# <font color='blue' size = "5">increasing with distance, one per data point </font>

# %%
active_func = 3 #RBF increasing with distance
# LHS, RHS = plt.subplot(121), plt.subplot(122)
N=1
xData = []
xData = np.append(xData, (0.5 * (1 - 2 * rng.random((N, 1)))))
yData = groundTruth(xData)
W,B = rngWeights(M,sigmaWeights,sigmaBiases)
y_s=[]
plot = False
for i in range(20): # in order to have less graphs, 2 points per graph in iteration less than 10 then 5 points -> graph
    if i < 10:
        if i % 2== 0 or i==0:
            plot = True
        else:
            plot = False
    elif i % 5 == 0:
        plot = True
    else:
        plot = False


    xData = np.append(xData, (0.5 * (1 - 2 * rng.random((N, 1)))))
    yData = groundTruth(xData)
    y, sig2 = BayesLinearRegression(W,B,alpha,beta,xData,x,active_func)
    upper = np.ravel(y + 2*np.sqrt(sig2))
    lower = np.ravel(y - 2*np.sqrt(sig2))

    if plot:
        LHS = plt.subplot()
        LHS.fill_between(np.ravel(x), lower, upper, facecolor='pink', interpolate=True, alpha=.5)
        LHS.plot(x, y, '-r', alpha=1)
        LHS.set_ylim(-2, 2)
        LHS.plot(x, groundTruth(x), ':g', xData, yData, 'ok')
        print(i)
        plt.show()

# # for the RHS, we just draw samples i.i.d at each x value in linspace
# for i in range(200):
#     z = rng.normal(y,np.sqrt(sig2))
#     RHS.plot(x,z,'.b',alpha= 0.1)
#     RHS.set_ylim(-2, 2)
#
# errors = np.abs(y-groundTruth(x))

LHS.plot(x,groundTruth(x),':g',xData,yData,'ok')
# RHS.plot(xData,yData,'ok')
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# 15
# ...

# %% [markdown]
# <font color='black' size = "5">from x to x^k </font>

# %%
def BayesLinearRegression_xToK(W,B,alpha,beta,xData,xQuery,active_func):

#     print(np.shape(W))
    Phi = doDesignMatrix(W,B,xData,active_func)
    invS = alpha*np.eye(M) + beta*np.dot(Phi.transpose(),Phi)
    S = np.linalg.inv(invS)
    regMoorePenrose = beta*np.dot(S, Phi.transpose()) #nb. the beta here "undoes" the one inside invS
#     print(type(regMoorePenrose))
    regM = []
    for reg in regMoorePenrose:
        row = 0
        for i in range(5):
            row+=reg[i]
        regM.append(row)
    
    regM = np.asarray(regM)
    regMoorePenrose = regM
    print("regMoorePenrose", np.shape(regMoorePenrose))
        
                
        
        
    wLMS = np.dot(regMoorePenrose, yData)
    phi = doDesignMatrix(W,B,xQuery,active_func)
    y = np.dot(phi,wLMS)
    sig2 = 1/beta + np.diag(np.dot(np.dot(phi, S), phi.transpose())).reshape(y.shape) 
    return (y, sig2)

# %%
k = 5 # the highest index of x 
N = 10
active_func = 1# RBF decreasing with distance


xData = 0.5*(1-2*rng.random((N,1)))
xData_x = xData #original x
yData = groundTruth(xData_x)

fig=plt.figure(figsize=(18, 6))

LHS = plt.subplot()
W,B = rngWeights(M,sigmaWeights,sigmaBiases)


xData_2 = []
xData_3 = []
xData_4 = []
xData_5 = []

for x in xData:
    xData_2.append(x**2)
    xData_3.append(x**3)
    xData_4.append(x**4)
    xData_5.append(x**5)

xData_modif = []


for i in range(len(xData)):
# xData[x,x^2,x^3,x^4,x^5]
#     xData_modif.append(xData[i][0])
#     xData_modif.append(xData_2[i][0])
#     xData_modif.append(xData_3[i][0])
#     xData_modif.append(xData_4[i][0])
#     xData_modif.append(xData_5[i][0])
      xData_modif = np.append(xData_modif, [xData[i][0], xData_2[i][0], xData_3[i][0], xData_4[i][0], xData_5[i][0]], axis=0)
# print(xData_modif)
# print("modif :", np.shape(xData_modif))

xData = xData_modif


print("xdata ", np.shape(xData))


y, sig2 = BayesLinearRegression_xToK(W,B,alpha,beta,xData,x,active_func)

upper = np.ravel(y + 2*np.sqrt(sig2))
lower = np.ravel(y - 2*np.sqrt(sig2))

LHS.fill_between(np.ravel(x), lower, upper, facecolor='pink', interpolate=True, alpha=.5)
LHS.plot(x,y,'-r',alpha=1)
LHS.set_ylim(-2,2)

# # for the RHS, we just draw samples i.i.d at each x value in linspace
# for i in range(200):
#     z = rng.normal(y,np.sqrt(sig2))
#     RHS.plot(x,z,'.b',alpha= 0.1)
#     RHS.set_ylim(-2, 2)
LHS.plot(x,groundTruth(x),':g',xData,yData,'ok')
# RHS.plot(xData,yData,'ok')
# Out:
# xdata  (50,)
# regMoorePenrose (100,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-274-76f5228622ae> in <module>
#      45
#      46
# ---> 47 y, sig2 = BayesLinearRegression_xToK(W,B,alpha,beta,xData,x,active_func)
#      48
#      49 upper = np.ravel(y + 2*np.sqrt(sig2))
#
# <ipython-input-273-39ac765e3647> in BayesLinearRegression_xToK(W, B, alpha, beta, xData, xQuery, active_func)
#      21
#      22
# ---> 23     wLMS = np.dot(regMoorePenrose, yData)
#      24     phi = doDesignMatrix(W,B,xQuery,active_func)
#      25     y = np.dot(phi,wLMS)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (100,) and (10,1) not aligned: 100 (dim 0) != 10 (dim 0)

# %% [markdown]
# <font size=4>Using rising powers of x, the models could be $w_0 + w_1x + w_2x^2....+w_kx^k =y $ for high dimensional inputs, we can still have a linear model, thanks to the non-linearity of the polynomial function.
#
#
#
# </font>

# %% [markdown]
# <font size =5 color = 'blue'>Question 3
# </font>

# %% [markdown]
# <font size = 4, color ="BLACK">Background:</font>
#     <font size=3>
# For generative classifiers, we aim to predict which the data most likely to be classified in class 1 or 2. That is we aim to model the joint probability p(x,y) and thus maximize the joint likelihood $$\sum_{n}logP(xn,yn)$$
#
# generative vs discriminative:$$$$
# Generative models capture the joint probability p(X, Y), or just p(X) if there are no labels.
# Discriminative models capture the conditional probability p(Y | X).
#
# Generative classifier:
# To get P(Y|X), estimate P(X|Y) and P(Y) from the data, multiply P(X|Y) and P(Y) according to bayes theorem.
# Discriminative classifier:
# Estimate P(Y|X) from the data</font>

# %% [markdown]
# <font size = 4, color = "blue"> Q3.i</font>

# %% [markdown]
# <font size=3>
# $$\underline{x} = N(\underline{x}|\underline{\mu},\sigma^2)$$
# In this cases we only have two classes. That gives us
# $$Z\in {(A,B)}$$
# $$P(Z|\underline{x}) = \frac{P(\underline{x}|Z)P(Z)}{P(\underline{x})}$$
# $$P(Z=A|\underline{x}) = \frac{\frac{1}{\sqrt{2\Pi\sigma^2}} e^{-\frac{1}{2\sigma^2}||\underline{x}-\mu_A||^2}}
#     {\sum_Z\frac{1}{\sqrt{2\Pi\sigma^2}} e^{-\frac{1}{2\sigma^2}||\underline{x}-\mu_Z'||^2 }}
# $$
# $$P(Z=B|\underline{x}) = \frac{\frac{1}{\sqrt{2\Pi\sigma^2}} e^{-\frac{1}{2\sigma^2}||\underline{x}-\mu_B||^2}}
#     {\sum_Z\frac{1}{\sqrt{2\Pi\sigma^2}} e^{-\frac{1}{2\sigma^2}||\underline{x}-\mu_Z'||^2 }}
# $$
# The decision boundary actually sitting at P(Z=A|x) = P(Z=B|x), which gives:
# $$P(Z=A|\underline{x})=P(Z=B|\underline{x})$$
# The denominator can cancel out by multiply both sides, then we can cancel exp(-1/2sigma^2).
# Then it becomes:
# $$\begin{equation*}
# e^{||\underline{x}-\mu_{A}||^2} = e^{||\underline{x} - \mu_{B}||^2}
# \end{equation*}$$
# LHS:
#     $$\sum_{d}(x_d - \mu_{A,d})^2 = \sum_{d} x_d^2 - 2\sum_{d}x_d\mu_{A,d} + \sum_{d}\mu_{A,d}^2$$
# RHS:
#     $$\sum_{d}(x_d - \mu_{B,d})^2 = \sum_{d} x_d^2 - 2\sum_{d}x_d\mu_{B,d} + \sum_{d}\mu_{B,d}^2$$
# Then $ \sum_{d} x_d^2$ been canceled and only left with:
# </font>

# %% [markdown]
# <font size=3>
# $$2\sum_{d} x_d(\mu_{A,d}-\mu_{B,d}) + \sum_{d}(\mu_{A,d}^2 - \mu_{B,d}^2) = 0$$
# And $ \sum_{d}(\mu_{A,d}^2 - \mu_{B,d}^2)$ is a constant number.
# So it can be seen as $(\mu_A-\mu_B)\underline{x} + C =0 $
# Hence it is a hyperplane.</font>

# %% [markdown]
# <font size =4, color = "blue">Q3.ii</font>

# %% [markdown]
# <font size=3>For example we say Z=(A,B,C) that is three classes. We can actually forms three surefaces. By doing (A,B),(B,C),(A,C) seperately. Let P(Z=A|x) = P(Z=B|x) we can find the decesion boundary between A,B. And repeat this step for other options. And we can find three surfaces. And these three surfaces could possiblely form a three dimensional obejct.</font>

# %% [markdown]
# <font size =4, color = "blue">Q3.iii</font>

# %% [markdown]
# <font size=3>Yes, Generative classifier can still work for categorical data. For generative model, we care about P(Z,x), which can be derive as $P(Z|\underline{x}) = \frac{P(\underline{x}|Z)P(Z)}{P(\underline{x})}$. If we know the prior of the dice, we can also work out the details about the classifier.</font>
